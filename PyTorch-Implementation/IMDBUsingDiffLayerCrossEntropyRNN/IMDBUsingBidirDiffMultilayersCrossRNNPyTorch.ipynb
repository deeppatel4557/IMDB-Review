# %%
import torch
from torchtext import data,datasets
import random
import torch.nn as nn
from torch import optim
import numpy as np
import time
import copy

# %% [markdown]
# **Step 1 : Instantiate Text and Label field**

# %%
SEED = 4

torch.manual_seed(SEED)
torch.backends.cudnn.deterministic = True
#create text field to store textdata
#tokenize text data with "spacy" tokenizer
TEXT = data.Field(tokenize = 'spacy')
#create label field to store labels in float
LABEL = data.LabelField(dtype = torch.float)

# %% [markdown]
# **Step 2 : Create data split**

# %%
train_data, test_data = datasets.IMDB.splits(TEXT, LABEL)
print(type(train_data))
print(len(train_data))
print(len(test_data))
# Out:
# downloading aclImdb_v1.tar.gz
# aclImdb_v1.tar.gz: 100%|██████████| 84.1M/84.1M [00:07<00:00, 12.0MB/s]
# <class 'torchtext.datasets.imdb.IMDB'>
# 25000
# 25000

# %%
#create train and validation split from train data
train_data, valid_data = train_data.split(random_state = random.seed(SEED))
#check size of splits
print(len(train_data))
print(len(valid_data))
print(len(test_data))
# Out:
# 17500
# 7500
# 25000

# %% [markdown]
# **Step 3 : Build vocabulary from training data**

# %%
MAX_VOCAB_SIZE = 10000

TEXT.build_vocab(train_data, max_size = MAX_VOCAB_SIZE)
LABEL.build_vocab(train_data)

print("Vocabulary size : ",len(TEXT.vocab))
print("No of different labels : ",len(LABEL.vocab))
# Out:
# Vocabulary size :  10002
# No of different labels :  2

# %%
#print most 20 frequently occured tokens in the corpus
print(TEXT.vocab.freqs.most_common(20))
# Out:
# [('the', 203653), (',', 192410), ('.', 165777), ('and', 109844), ('a', 109404), ('of', 100996), ('to', 94003), ('is', 76197), ('in', 61428), ('I', 54258), ('it', 53583), ('that', 49228), ('"', 43922), ("'s", 43359), ('this', 42349), ('-', 36831), ('/><br', 35639), ('was', 35187), ('as', 30351), ('with', 29982)]

# %%
print(TEXT.vocab.itos[:10])
print(LABEL.vocab.stoi)
# Out:
# ['<unk>', '<pad>', 'the', ',', '.', 'and', 'a', 'of', 'to', 'is']
# defaultdict(<function _default_unk_index at 0x7fe386b98158>, {'neg': 0, 'pos': 1})

# %% [markdown]
# **Step 4 : Create dataloader**

# %%
BATCH_SIZE = 32

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

trainloader, valloader, testloader = data.BucketIterator.splits(
    (train_data, valid_data, test_data), 
    batch_size = BATCH_SIZE,
    device = device)

# %% [markdown]
# **Step 5 : Build model**

# %%
class RNN(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, output_dim):
        
        super().__init__()
        
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        
        self.lstm=nn.RNN(embedding_dim, 
                           hidden_dim[0], 
                           num_layers=1, 
                           bidirectional=True, 
                           )
        self.lstm2=nn.RNN(hidden_dim[0]*2, 
                           hidden_dim[1], 
                           num_layers=1, 
                           bidirectional=True, 
                           )
        
        self.fc = nn.Linear(hidden_dim[1]*2, 16)
        self.fc2=nn.Linear(16,output_dim)
    def forward(self, text):

        #text = [sent len, batch size]
        
        embedded = self.embedding(text)
        
        #embedded = [sent len, batch size, emb dim]
        
        output, hidden = self.lstm(embedded)
        _, hidden = self.lstm2(output)
        #print(output.shape,hidden.shape,cell.shape)
        #here the return fc have output dim=(batch_size,1)
        hidden=torch.cat((hidden[-2,:,:], hidden[-1,:,:]), dim = 1)
        #assert torch.equal(output[-1,:,:], hidden.squeeze(0))
        ans=self.fc(hidden)
        ans=self.fc2(ans)
        return ans

# %% [markdown]
# **Step 5 : Instanstiate Loss function, Optimizer, Model**

# %%
VOCAB_SIZE = len(TEXT.vocab)
EMBEDDING_DIM = 64
HIDDEN_DIM = [32,64]
OUTPUT_DIM = 2

# %%
def evaluation_gpu(preds, y):
    max_preds = preds.argmax(dim = 1, keepdim = True) # get the index of the max probability
    correct = max_preds.squeeze(1).eq(y)
    return correct.sum() / torch.FloatTensor([y.shape[0]])

# %%
def fit_gpu(trainloader,valloader,model,opt,loss_fn,epochs=25):
        #callback=StopatLossValue()
        time0=time.time()
        trainloss=[]
        valloss=[]
        trainacclist=[]
        valacclist=[]
        min_valloss=10000000.0000000
        min_trainloss=10000000.0000000
        max_valacc=0.0
        max_trainacc=0.0
        
        for epoch in range(epochs):
            runningtrain_loss=0
            runningval_loss=0
            #init_fn()
            for i, data in enumerate(trainloader, 0):

                #inputs, labels = data
                #inputs=inputs.to(device)
                #labels=labels.to(device)

                #forward pass
                predtrain=model(data.text)
                label=data.label.long()
                loss = loss_fn(predtrain,label)
                trainacc=evaluation_gpu(predtrain,data.label)
                #backward and optimize
                opt.zero_grad()
                loss.backward()
                opt.step()
                
                
                runningtrain_loss += loss.item()
            #init_fn()
            for i, data in enumerate(valloader,0):
                #inputs, labels = data
                #inputs=inputs.to(device)
                #labels=labels.to(device)

                #forward pass
                predval=model(data.text)
                label=data.label.long()
                loss = loss_fn(predval, label)
                valacc=evaluation_gpu(predval,data.label)

                runningval_loss += loss.item()
            avgval_loss=runningval_loss/len(valloader)
            avgtrain_loss=runningtrain_loss/len(trainloader)
            if (avgval_loss<min_valloss):
                min_valloss=avgval_loss    
                vallossmodel=copy.deepcopy(model.state_dict())
            if (avgtrain_loss<min_trainloss):
                min_trainloss=avgtrain_loss
                trainlossmodel=copy.deepcopy(model.state_dict())
            trainacclist.append(trainacc)
            valacclist.append(valacc)
            if (trainacc>max_trainacc):
                max_trainacc=trainacc
                trainaccmodel=copy.deepcopy(model.state_dict())
            if (valacc>max_valacc):
                max_trainacc=valacc
                valaccmodel=copy.deepcopy(model.state_dict())      
            print("Minimum training Loss :",min_trainloss,"| Minimum validation Loss :",min_valloss) 
            print("Epoch {} - Training loss: {}".format(epoch,avgtrain_loss ),"| validation loss: {}".format(avgval_loss))    
            print('Epoch: %d/%d, Train acc: %0.2f' % (epoch, epochs-1,trainacc ),'| val acc: %0.2f' % (valacc))
            print('------------------------------------------------------------------------------------------')
            trainloss.append(avgtrain_loss)       
            valloss.append(avgval_loss)
            #vis.line(Y=avgtrain_loss, opts=dict(showlegend=True))
        print("Training Time(in minutes) =",(time.time()-time0)/60)    
        return vallossmodel,trainlossmodel,valaccmodel,trainaccmodel,trainloss,valloss,trainacclist,valacclist

# %%
model = RNN(VOCAB_SIZE, EMBEDDING_DIM, HIDDEN_DIM, OUTPUT_DIM)
model = model.to(device)
opt = optim.Adam(model.parameters())
loss_fn = nn.CrossEntropyLoss()
vallossmodel,trainlossmodel,valaccmodel,trainaccmodel,trainloss,valloss,trainacclist,valacclist=fit_gpu(trainloader,valloader,model,opt,loss_fn)
# Out:
# Minimum training Loss : 0.6864719932432366 | Minimum validation Loss : 0.6631382396880616
# Epoch 0 - Training loss: 0.6864719932432366 | validation loss: 0.6631382396880616
# Epoch: 0/24, Train acc: 0.59 | val acc: 0.50
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.6574732174167249 | Minimum validation Loss : 0.6488216775528928
# Epoch 1 - Training loss: 0.6574732174167249 | validation loss: 0.6488216775528928
# Epoch: 1/24, Train acc: 0.69 | val acc: 0.58
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.6273177607730712 | Minimum validation Loss : 0.6488216775528928
# Epoch 2 - Training loss: 0.6273177607730712 | validation loss: 0.6644095450005633
# Epoch: 2/24, Train acc: 0.56 | val acc: 0.50
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.6025028913069033 | Minimum validation Loss : 0.6169610849086274
# Epoch 3 - Training loss: 0.6025028913069033 | validation loss: 0.6169610849086274
# Epoch: 3/24, Train acc: 0.69 | val acc: 0.67
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.5906318907219051 | Minimum validation Loss : 0.6169610849086274
# Epoch 4 - Training loss: 0.5906318907219051 | validation loss: 0.6738576673446818
# Epoch: 4/24, Train acc: 0.69 | val acc: 0.58
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.542098647824589 | Minimum validation Loss : 0.6078684328718388
# Epoch 5 - Training loss: 0.542098647824589 | validation loss: 0.6078684328718388
# Epoch: 5/24, Train acc: 0.75 | val acc: 0.83
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.49387695312064134 | Minimum validation Loss : 0.5970818774497255
# Epoch 6 - Training loss: 0.49387695312064134 | validation loss: 0.5970818774497255
# Epoch: 6/24, Train acc: 0.91 | val acc: 0.67
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.4848914489122806 | Minimum validation Loss : 0.5970818774497255
# Epoch 7 - Training loss: 0.4848914489122806 | validation loss: 0.6336617590265071
# Epoch: 7/24, Train acc: 0.78 | val acc: 0.58
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.4848914489122806 | Minimum validation Loss : 0.5970818774497255
# Epoch 8 - Training loss: 0.4917368848809812 | validation loss: 0.6258867785017541
# Epoch: 8/24, Train acc: 0.75 | val acc: 0.83
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.4848914489122806 | Minimum validation Loss : 0.5970818774497255
# Epoch 9 - Training loss: 0.4850391372084836 | validation loss: 0.7007743447384935
# Epoch: 9/24, Train acc: 0.84 | val acc: 0.58
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.4848914489122806 | Minimum validation Loss : 0.5970818774497255
# Epoch 10 - Training loss: 0.5509104327702217 | validation loss: 0.6718846655906515
# Epoch: 10/24, Train acc: 0.59 | val acc: 0.75
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.4848914489122806 | Minimum validation Loss : 0.5970818774497255
# Epoch 11 - Training loss: 0.5348017572593863 | validation loss: 0.6534862414319464
# Epoch: 11/24, Train acc: 0.84 | val acc: 0.75
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.484815374071245 | Minimum validation Loss : 0.5970818774497255
# Epoch 12 - Training loss: 0.484815374071245 | validation loss: 0.6116348611547592
# Epoch: 12/24, Train acc: 0.59 | val acc: 0.58
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.484815374071245 | Minimum validation Loss : 0.5970818774497255
# Epoch 13 - Training loss: 0.5391064800281193 | validation loss: 0.6024684065199913
# Epoch: 13/24, Train acc: 0.84 | val acc: 0.50
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.4394395870090185 | Minimum validation Loss : 0.5970818774497255
# Epoch 14 - Training loss: 0.4394395870090185 | validation loss: 0.610133753685241
# Epoch: 14/24, Train acc: 0.78 | val acc: 0.58
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.4394395870090185 | Minimum validation Loss : 0.5970818774497255
# Epoch 15 - Training loss: 0.48997150808300355 | validation loss: 0.6392347635106838
# Epoch: 15/24, Train acc: 0.75 | val acc: 0.67
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.4394395870090185 | Minimum validation Loss : 0.5970818774497255
# Epoch 16 - Training loss: 0.4451931317556493 | validation loss: 0.615710182139214
# Epoch: 16/24, Train acc: 0.84 | val acc: 0.67
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.4342167485076287 | Minimum validation Loss : 0.5970818774497255
# Epoch 17 - Training loss: 0.4342167485076287 | validation loss: 0.6459580976912316
# Epoch: 17/24, Train acc: 0.78 | val acc: 0.50
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.41380940740025673 | Minimum validation Loss : 0.5970818774497255
# Epoch 18 - Training loss: 0.41380940740025673 | validation loss: 0.6739284588935527
# Epoch: 18/24, Train acc: 0.84 | val acc: 0.50
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.37863901339239786 | Minimum validation Loss : 0.5970818774497255
# Epoch 19 - Training loss: 0.37863901339239786 | validation loss: 0.6289807507332336
# Epoch: 19/24, Train acc: 0.81 | val acc: 0.58
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.3457503385664776 | Minimum validation Loss : 0.5970818774497255
# Epoch 20 - Training loss: 0.3457503385664776 | validation loss: 0.6431091028325101
# Epoch: 20/24, Train acc: 0.78 | val acc: 0.58
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.3457503385664776 | Minimum validation Loss : 0.5970818774497255
# Epoch 21 - Training loss: 0.35979712212379933 | validation loss: 0.7132439869515439
# Epoch: 21/24, Train acc: 0.94 | val acc: 0.50
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.3457503385664776 | Minimum validation Loss : 0.5970818774497255
# Epoch 22 - Training loss: 0.3867517779334372 | validation loss: 0.6517789316938278
# Epoch: 22/24, Train acc: 0.59 | val acc: 0.33
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.3457503385664776 | Minimum validation Loss : 0.5970818774497255
# Epoch 23 - Training loss: 0.36293290488735197 | validation loss: 0.6777873753233159
# Epoch: 23/24, Train acc: 0.81 | val acc: 0.50
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.32182484707187253 | Minimum validation Loss : 0.5970818774497255
# Epoch 24 - Training loss: 0.32182484707187253 | validation loss: 0.6844034381369327
# Epoch: 24/24, Train acc: 0.84 | val acc: 0.58
# ------------------------------------------------------------------------------------------
# Training Time(in minutes) = 74.2031799753507

# %%
def evaluate(model, iterator, criterion):
    
    epoch_loss = 0
    epoch_acc = 0
    
    model.eval()
    
    with torch.no_grad():
    
        for batch in iterator:
            
            predictions = model(batch.text)
            label=batch.label.long()
            loss = criterion(predictions, label)
            
            acc = evaluation_gpu(predictions, batch.label)

            epoch_loss += loss.item()
            epoch_acc += acc.item()
        
    return epoch_loss / len(iterator), epoch_acc / len(iterator)

# %%
model.load_state_dict(valaccmodel)
test_loss, test_acc = evaluate(model, testloader, loss_fn)

print(f'Test Loss: {test_loss:.3f} | Test Acc: {test_acc*100:.2f}%')
# Out:
# Test Loss: 0.692 | Test Acc: 67.89%

# %%
import matplotlib.pyplot as plt

epochs=len(trainloss)
plt.plot([i for i in range(1,epochs+1)],trainloss,label="Train_loss")
plt.plot([i for i in range(1,epochs+1)],valloss,label="Validation_loss")
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
plt.plot([i for i in range(1,epochs+1)],trainacclist,label="Train_Accuracy")
plt.plot([i for i in range(1,epochs+1)],valacclist,label="Validation_Accuracy")
plt.xlabel('epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
