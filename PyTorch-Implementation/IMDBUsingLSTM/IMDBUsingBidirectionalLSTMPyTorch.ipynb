# %%
import torch
from torchtext import data,datasets
import random
import torch.nn as nn
from torch import optim
import numpy as np
import time
import copy

# %% [markdown]
# **Step 1 : Instantiate Text and Label field**

# %%
SEED = 4

torch.manual_seed(SEED)
torch.backends.cudnn.deterministic = True
#create text field to store textdata
#tokenize text data with "spacy" tokenizer
TEXT = data.Field(tokenize = 'spacy')
#create label field to store labels in float
LABEL = data.LabelField(dtype = torch.float)

# %% [markdown]
# **Step 2 : Create data split**

# %%
train_data, test_data = datasets.IMDB.splits(TEXT, LABEL)
print(type(train_data))
print(len(train_data))
print(len(test_data))
# Out:
# <class 'torchtext.datasets.imdb.IMDB'>
# 25000
# 25000

# %%
#create train and validation split from train data
train_data, valid_data = train_data.split(random_state = random.seed(SEED))
#check size of splits
print(len(train_data))
print(len(valid_data))
print(len(test_data))
# Out:
# 17500
# 7500
# 25000

# %% [markdown]
# **Step 3 : Build vocabulary from training data**

# %%
MAX_VOCAB_SIZE = 10000

TEXT.build_vocab(train_data, max_size = MAX_VOCAB_SIZE)
LABEL.build_vocab(train_data)

print("Vocabulary size : ",len(TEXT.vocab))
print("No of different labels : ",len(LABEL.vocab))
# Out:
# Vocabulary size :  10002
# No of different labels :  2

# %%
#print most 20 frequently occured tokens in the corpus
print(TEXT.vocab.freqs.most_common(20))
# Out:
# [('the', 202984), (',', 192815), ('.', 166441), ('a', 109530), ('and', 109365), ('of', 100797), ('to', 93333), ('is', 76572), ('in', 61364), ('I', 54228), ('it', 53270), ('that', 49046), ('"', 44544), ("'s", 43284), ('this', 42307), ('-', 36921), ('/><br', 35672), ('was', 35011), ('as', 30544), ('with', 29785)]

# %%
print(TEXT.vocab.itos[:10])
print(LABEL.vocab.stoi)
# Out:
# ['<unk>', '<pad>', 'the', ',', '.', 'a', 'and', 'of', 'to', 'is']
# defaultdict(<function _default_unk_index at 0x7f939af16e18>, {'neg': 0, 'pos': 1})

# %% [markdown]
# **Step 4 : Create dataloader**

# %%
BATCH_SIZE = 32

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

trainloader, valloader, testloader = data.BucketIterator.splits(
    (train_data, valid_data, test_data), 
    batch_size = BATCH_SIZE,
    device = device)

# %% [markdown]
# **Step 5 : Build model**

# %%
class LSTM(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, output_dim):
        
        super().__init__()
        
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        
        self.lstm=nn.LSTM(embedding_dim, 
                           hidden_dim, 
                           num_layers=2, 
                           bidirectional=True, 
                           )
        
        self.fc = nn.Linear(hidden_dim*2, 16)
        self.fc2=nn.Linear(16,output_dim)
        self.soft=nn.Softmax(2)
    def forward(self, text):

        #text = [sent len, batch size]
        
        embedded = self.embedding(text)
        
        #embedded = [sent len, batch size, emb dim]
        
        output, (hidden,cell) = self.lstm(embedded)
        #print(output.shape,hidden.shape,cell.shape)
        #here the return fc have output dim=(batch_size,1)
        hidden=torch.cat((hidden[-2,:,:], hidden[-1,:,:]), dim = 1)
        #assert torch.equal(output[-1,:,:], hidden.squeeze(0))
        ans=self.fc(hidden)
        ans=self.fc2(ans)
        return ans

# %% [markdown]
# **Step 5 : Instanstiate Loss function, Optimizer, Model**

# %%
VOCAB_SIZE = len(TEXT.vocab)
EMBEDDING_DIM = 64
HIDDEN_DIM = 32
OUTPUT_DIM = 1

# %%
def evaluation_gpu(preds, y):
    #round predictions to the closest integer
    rounded_preds = torch.round(torch.sigmoid(preds))
    correct = (rounded_preds == y).float() #convert into float for division 
    acc = correct.sum() / len(correct)
    return acc

# %%
def fit_gpu(trainloader,valloader,model,opt,loss_fn,epochs=25):
        #callback=StopatLossValue()
        time0=time.time()
        trainloss=[]
        valloss=[]
        trainacclist=[]
        valacclist=[]
        min_valloss=10000000.0000000
        min_trainloss=10000000.0000000
        max_valacc=0.0
        max_trainacc=0.0
        
        for epoch in range(epochs):
            runningtrain_loss=0
            runningval_loss=0
            #init_fn()
            for i, data in enumerate(trainloader, 0):

                #inputs, labels = data
                #inputs=inputs.to(device)
                #labels=labels.to(device)

                #forward pass
                predtrain=model(data.text).squeeze(1)
                loss = loss_fn(predtrain, data.label)
                trainacc=evaluation_gpu(predtrain,data.label)
                #backward and optimize
                opt.zero_grad()
                loss.backward()
                opt.step()
                
                
                runningtrain_loss += loss.item()
            #init_fn()
            for i, data in enumerate(valloader,0):
                #inputs, labels = data
                #inputs=inputs.to(device)
                #labels=labels.to(device)

                #forward pass
                predval=model(data.text).squeeze(1)
                loss = loss_fn(predval, data.label)
                valacc=evaluation_gpu(predval,data.label)

                runningval_loss += loss.item()
            avgval_loss=runningval_loss/len(valloader)
            avgtrain_loss=runningtrain_loss/len(trainloader)
            if (avgval_loss<min_valloss):
                min_valloss=avgval_loss    
                vallossmodel=copy.deepcopy(model.state_dict())
            if (avgtrain_loss<min_trainloss):
                min_trainloss=avgtrain_loss
                trainlossmodel=copy.deepcopy(model.state_dict())
            trainacclist.append(trainacc)
            valacclist.append(valacc)
            if (trainacc>max_trainacc):
                max_trainacc=trainacc
                trainaccmodel=copy.deepcopy(model.state_dict())
            if (valacc>max_valacc):
                max_trainacc=valacc
                valaccmodel=copy.deepcopy(model.state_dict())      
            print("Minimum training Loss :",min_trainloss,"| Minimum validation Loss :",min_valloss) 
            print("Epoch {} - Training loss: {}".format(epoch,avgtrain_loss ),"| validation loss: {}".format(avgval_loss))    
            print('Epoch: %d/%d, Train acc: %0.2f' % (epoch, epochs-1,trainacc ),'| val acc: %0.2f' % (valacc))
            print('------------------------------------------------------------------------------------------')
            trainloss.append(avgtrain_loss)       
            valloss.append(avgval_loss)
            #vis.line(Y=avgtrain_loss, opts=dict(showlegend=True))
        print("Training Time(in minutes) =",(time.time()-time0)/60)    
        return vallossmodel,trainlossmodel,valaccmodel,trainaccmodel,trainloss,valloss,trainacclist,valacclist

# %%
model = LSTM(VOCAB_SIZE, EMBEDDING_DIM, HIDDEN_DIM, OUTPUT_DIM)
model = model.to(device)
opt = optim.Adam(model.parameters())
loss_fn = nn.BCEWithLogitsLoss()
vallossmodel,trainlossmodel,valaccmodel,trainaccmodel,trainloss,valloss,trainacclist,valacclist=fit_gpu(trainloader,valloader,model,opt,loss_fn)
# Out:
# Minimum training Loss : 0.6593715861249013 | Minimum validation Loss : 0.617231529443822
# Epoch 0 - Training loss: 0.6593715861249013 | validation loss: 0.617231529443822
# Epoch: 0/24, Train acc: 0.69 | val acc: 0.58
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.5726865416688937 | Minimum validation Loss : 0.5654640575672718
# Epoch 1 - Training loss: 0.5726865416688937 | validation loss: 0.5654640575672718
# Epoch: 1/24, Train acc: 0.59 | val acc: 0.58
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.47731075837690606 | Minimum validation Loss : 0.4651542694010633
# Epoch 2 - Training loss: 0.47731075837690606 | validation loss: 0.4651542694010633
# Epoch: 2/24, Train acc: 0.78 | val acc: 0.58
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.3551043904568639 | Minimum validation Loss : 0.38741655774573064
# Epoch 3 - Training loss: 0.3551043904568639 | validation loss: 0.38741655774573064
# Epoch: 3/24, Train acc: 0.72 | val acc: 0.83
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.2723619782483338 | Minimum validation Loss : 0.38741655774573064
# Epoch 4 - Training loss: 0.2723619782483338 | validation loss: 0.4023477145173448
# Epoch: 4/24, Train acc: 0.94 | val acc: 0.75
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.2152490323406033 | Minimum validation Loss : 0.342167478324251
# Epoch 5 - Training loss: 0.2152490323406033 | validation loss: 0.342167478324251
# Epoch: 5/24, Train acc: 0.97 | val acc: 0.92
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.16405320013285882 | Minimum validation Loss : 0.342167478324251
# Epoch 6 - Training loss: 0.16405320013285882 | validation loss: 0.35880306730879113
# Epoch: 6/24, Train acc: 0.97 | val acc: 0.83
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.13848150660959796 | Minimum validation Loss : 0.342167478324251
# Epoch 7 - Training loss: 0.13848150660959796 | validation loss: 0.36945209428668024
# Epoch: 7/24, Train acc: 1.00 | val acc: 1.00
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.10001654723247129 | Minimum validation Loss : 0.342167478324251
# Epoch 8 - Training loss: 0.10001654723247129 | validation loss: 0.42878127514998965
# Epoch: 8/24, Train acc: 0.88 | val acc: 0.92
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.07734235896519513 | Minimum validation Loss : 0.342167478324251
# Epoch 9 - Training loss: 0.07734235896519513 | validation loss: 0.5229161154716573
# Epoch: 9/24, Train acc: 1.00 | val acc: 1.00
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.06476118728574672 | Minimum validation Loss : 0.342167478324251
# Epoch 10 - Training loss: 0.06476118728574672 | validation loss: 0.5382597468634869
# Epoch: 10/24, Train acc: 0.91 | val acc: 0.92
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.048537012532700735 | Minimum validation Loss : 0.342167478324251
# Epoch 11 - Training loss: 0.048537012532700735 | validation loss: 0.5064533543792811
# Epoch: 11/24, Train acc: 0.97 | val acc: 0.83
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.03629315151344351 | Minimum validation Loss : 0.342167478324251
# Epoch 12 - Training loss: 0.03629315151344351 | validation loss: 0.5627759762029064
# Epoch: 12/24, Train acc: 0.97 | val acc: 0.92
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.03629315151344351 | Minimum validation Loss : 0.342167478324251
# Epoch 13 - Training loss: 0.04261925260338871 | validation loss: 0.587144519019119
# Epoch: 13/24, Train acc: 1.00 | val acc: 0.92
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.02121942175709314 | Minimum validation Loss : 0.342167478324251
# Epoch 14 - Training loss: 0.02121942175709314 | validation loss: 0.7219039397710498
# Epoch: 14/24, Train acc: 1.00 | val acc: 0.92
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.02121942175709314 | Minimum validation Loss : 0.342167478324251
# Epoch 15 - Training loss: 0.024801479600115816 | validation loss: 0.6110964237018786
# Epoch: 15/24, Train acc: 1.00 | val acc: 1.00
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.02121942175709314 | Minimum validation Loss : 0.342167478324251
# Epoch 16 - Training loss: 0.023219154163249267 | validation loss: 0.6969514024384478
# Epoch: 16/24, Train acc: 1.00 | val acc: 0.92
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.017462764217480387 | Minimum validation Loss : 0.342167478324251
# Epoch 17 - Training loss: 0.017462764217480387 | validation loss: 0.686477202788352
# Epoch: 17/24, Train acc: 1.00 | val acc: 1.00
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.013679919223797209 | Minimum validation Loss : 0.342167478324251
# Epoch 18 - Training loss: 0.013679919223797209 | validation loss: 0.6880073190577566
# Epoch: 18/24, Train acc: 1.00 | val acc: 0.92
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.013679919223797209 | Minimum validation Loss : 0.342167478324251
# Epoch 19 - Training loss: 0.02309266734559479 | validation loss: 0.7206189823713391
# Epoch: 19/24, Train acc: 1.00 | val acc: 0.92
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.012838122838510284 | Minimum validation Loss : 0.342167478324251
# Epoch 20 - Training loss: 0.012838122838510284 | validation loss: 0.8016381964642316
# Epoch: 20/24, Train acc: 1.00 | val acc: 0.92
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.012838122838510284 | Minimum validation Loss : 0.342167478324251
# Epoch 21 - Training loss: 0.020736806263157367 | validation loss: 0.6015895447039857
# Epoch: 21/24, Train acc: 1.00 | val acc: 0.92
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.009642091514983247 | Minimum validation Loss : 0.342167478324251
# Epoch 22 - Training loss: 0.009642091514983247 | validation loss: 0.9486734855523768
# Epoch: 22/24, Train acc: 1.00 | val acc: 0.92
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.009569525693139978 | Minimum validation Loss : 0.342167478324251
# Epoch 23 - Training loss: 0.009569525693139978 | validation loss: 0.7241251665781787
# Epoch: 23/24, Train acc: 1.00 | val acc: 1.00
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.007231580065330277 | Minimum validation Loss : 0.342167478324251
# Epoch 24 - Training loss: 0.007231580065330277 | validation loss: 0.8368032489120564
# Epoch: 24/24, Train acc: 1.00 | val acc: 0.92
# ------------------------------------------------------------------------------------------
# Training Time(in minutes) = 24.84656499226888

# %%
def evaluate(model, iterator, criterion):
    
    epoch_loss = 0
    epoch_acc = 0
    
    model.eval()
    
    with torch.no_grad():
    
        for batch in iterator:
            
            predictions = model(batch.text).squeeze(1)
            
            loss = criterion(predictions, batch.label)
            
            acc = evaluation_gpu(predictions, batch.label)

            epoch_loss += loss.item()
            epoch_acc += acc.item()
        
    return epoch_loss / len(iterator), epoch_acc / len(iterator)

# %%
model.load_state_dict(valaccmodel)
test_loss, test_acc = evaluate(model, testloader, loss_fn)

print(f'Test Loss: {test_loss:.3f} | Test Acc: {test_acc*100:.2f}%')
# Out:
# Test Loss: 0.891 | Test Acc: 86.02%

# %%
import matplotlib.pyplot as plt

epochs=len(trainloss)
plt.plot([i for i in range(1,epochs+1)],trainloss,label="Train_loss")
plt.plot([i for i in range(1,epochs+1)],valloss,label="Validation_loss")
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
plt.plot([i for i in range(1,epochs+1)],trainacclist,label="Train_Accuracy")
plt.plot([i for i in range(1,epochs+1)],valacclist,label="Validation_Accuracy")
plt.xlabel('epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
