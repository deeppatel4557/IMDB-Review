# %%
import torch
from torchtext import data,datasets
import random
import torch.nn as nn
from torch import optim
import numpy as np
import time
import copy

# %% [markdown]
# **Step 1 : Instantiate Text and Label field**

# %%
SEED = 4

torch.manual_seed(SEED)
torch.backends.cudnn.deterministic = True
#create text field to store textdata
#tokenize text data with "spacy" tokenizer
TEXT = data.Field(tokenize = 'spacy')
#create label field to store labels in float
LABEL = data.LabelField(dtype = torch.float)

# %% [markdown]
# **Step 2 : Create data split**

# %%
train_data, test_data = datasets.IMDB.splits(TEXT, LABEL)
print(type(train_data))
print(len(train_data))
print(len(test_data))
# Out:
# aclImdb_v1.tar.gz:   0%|          | 0.00/84.1M [00:00<?, ?B/s]
# downloading aclImdb_v1.tar.gz
# aclImdb_v1.tar.gz: 100%|██████████| 84.1M/84.1M [00:02<00:00, 38.4MB/s]
# <class 'torchtext.datasets.imdb.IMDB'>
# 25000
# 25000

# %%
#create train and validation split from train data
train_data, valid_data = train_data.split(random_state = random.seed(SEED))
#check size of splits
print(len(train_data))
print(len(valid_data))
print(len(test_data))
# Out:
# 17500
# 7500
# 25000

# %% [markdown]
# **Step 3 : Build vocabulary from training data**

# %%
MAX_VOCAB_SIZE = 10000

TEXT.build_vocab(train_data, max_size = MAX_VOCAB_SIZE)
LABEL.build_vocab(train_data)

print("Vocabulary size : ",len(TEXT.vocab))
print("No of different labels : ",len(LABEL.vocab))
# Out:
# Vocabulary size :  10002
# No of different labels :  2

# %%
#print most 20 frequently occured tokens in the corpus
print(TEXT.vocab.freqs.most_common(20))
# Out:
# [('the', 202646), (',', 193228), ('.', 166193), ('and', 109707), ('a', 109478), ('of', 100880), ('to', 93644), ('is', 76705), ('in', 61392), ('I', 54349), ('it', 53446), ('that', 49362), ('"', 44311), ("'s", 43534), ('this', 42484), ('-', 37079), ('/><br', 35903), ('was', 35116), ('as', 30538), ('with', 30072)]

# %%
print(TEXT.vocab.itos[:10])
print(LABEL.vocab.stoi)
# Out:
# ['<unk>', '<pad>', 'the', ',', '.', 'and', 'a', 'of', 'to', 'is']
# defaultdict(<function _default_unk_index at 0x7f6446c97158>, {'neg': 0, 'pos': 1})

# %% [markdown]
# **Step 4 : Create dataloader**

# %%
BATCH_SIZE = 32

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

trainloader, valloader, testloader = data.BucketIterator.splits(
    (train_data, valid_data, test_data), 
    batch_size = BATCH_SIZE,
    device = device)

# %% [markdown]
# **Step 5 : Build model**

# %%
class LSTM(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, output_dim):
        
        super().__init__()
        
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        
        self.lstm=nn.LSTM(embedding_dim, 
                           hidden_dim[0], 
                           num_layers=1, 
                           bidirectional=True, 
                           )
        self.lstm2=nn.LSTM(hidden_dim[0],hidden_dim[1],
                           num_layers=1,bidirectional=True)
        self.fc = nn.Linear(hidden_dim[1]*2, 16)
        self.fc2=nn.Linear(16,output_dim)
        self.soft=nn.Softmax(2)
    def forward(self, text):

        #text = [sent len, batch size]
        
        embedded = self.embedding(text)
        
        #embedded = [sent len, batch size, emb dim]
        
        _, (hidden,cell) = self.lstm(embedded)
        _, (hidden,cell) = self.lstm2(hidden)
        #print(output.shape,hidden.shape,cell.shape)
        #here the return fc have output dim=(batch_size,1)
        hidden=torch.cat((hidden[-2,:,:], hidden[-1,:,:]), dim = 1)
        #assert torch.equal(output[-1,:,:], hidden.squeeze(0))
        ans=self.fc(hidden)
        ans=self.fc2(ans)
        return ans

# %% [markdown]
# **Step 5 : Instanstiate Loss function, Optimizer, Model**

# %%
VOCAB_SIZE = len(TEXT.vocab)
EMBEDDING_DIM = 64
HIDDEN_DIM = [32,64]
OUTPUT_DIM = 1

# %%
def evaluation_gpu(preds, y):
    #round predictions to the closest integer
    rounded_preds = torch.round(torch.sigmoid(preds))
    correct = (rounded_preds == y).float() #convert into float for division 
    acc = correct.sum() / len(correct)
    return acc

# %%
def fit_gpu(trainloader,valloader,model,opt,loss_fn,epochs=25):
        #callback=StopatLossValue()
        time0=time.time()
        trainloss=[]
        valloss=[]
        trainacclist=[]
        valacclist=[]
        min_valloss=10000000.0000000
        min_trainloss=10000000.0000000
        max_valacc=0.0
        max_trainacc=0.0
        
        for epoch in range(epochs):
            runningtrain_loss=0
            runningval_loss=0
            #init_fn()
            for i, data in enumerate(trainloader, 0):

                #inputs, labels = data
                #inputs=inputs.to(device)
                #labels=labels.to(device)

                #forward pass
                predtrain=model(data.text).squeeze(1)
                loss = loss_fn(predtrain, data.label)
                trainacc=evaluation_gpu(predtrain,data.label)
                #backward and optimize
                opt.zero_grad()
                loss.backward()
                opt.step()
                
                
                runningtrain_loss += loss.item()
            #init_fn()
            for i, data in enumerate(valloader,0):
                #inputs, labels = data
                #inputs=inputs.to(device)
                #labels=labels.to(device)

                #forward pass
                predval=model(data.text).squeeze(1)
                loss = loss_fn(predval, data.label)
                valacc=evaluation_gpu(predval,data.label)

                runningval_loss += loss.item()
            avgval_loss=runningval_loss/len(valloader)
            avgtrain_loss=runningtrain_loss/len(trainloader)
            if (avgval_loss<min_valloss):
                min_valloss=avgval_loss    
                vallossmodel=copy.deepcopy(model.state_dict())
            if (avgtrain_loss<min_trainloss):
                min_trainloss=avgtrain_loss
                trainlossmodel=copy.deepcopy(model.state_dict())
            trainacclist.append(trainacc)
            valacclist.append(valacc)
            if (trainacc>max_trainacc):
                max_trainacc=trainacc
                trainaccmodel=copy.deepcopy(model.state_dict())
            if (valacc>max_valacc):
                max_trainacc=valacc
                valaccmodel=copy.deepcopy(model.state_dict())      
            print("Minimum training Loss :",min_trainloss,"| Minimum validation Loss :",min_valloss) 
            print("Epoch {} - Training loss: {}".format(epoch,avgtrain_loss ),"| validation loss: {}".format(avgval_loss))    
            print('Epoch: %d/%d, Train acc: %0.2f' % (epoch, epochs-1,trainacc ),'| val acc: %0.2f' % (valacc))
            print('------------------------------------------------------------------------------------------')
            trainloss.append(avgtrain_loss)       
            valloss.append(avgval_loss)
            #vis.line(Y=avgtrain_loss, opts=dict(showlegend=True))
        print("Training Time(in minutes) =",(time.time()-time0)/60)    
        return vallossmodel,trainlossmodel,valaccmodel,trainaccmodel,trainloss,valloss,trainacclist,valacclist

# %%
model = LSTM(VOCAB_SIZE, EMBEDDING_DIM, HIDDEN_DIM, OUTPUT_DIM)
model = model.to(device)
opt = optim.Adam(model.parameters())
loss_fn = nn.BCEWithLogitsLoss()
vallossmodel,trainlossmodel,valaccmodel,trainaccmodel,trainloss,valloss,trainacclist,valacclist=fit_gpu(trainloader,valloader,model,opt,loss_fn)
# Out:
# Minimum training Loss : 0.6716479103896474 | Minimum validation Loss : 0.6550814359746081
# Epoch 0 - Training loss: 0.6716479103896474 | validation loss: 0.6550814359746081
# Epoch: 0/24, Train acc: 0.59 | val acc: 0.42
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.6096912217096612 | Minimum validation Loss : 0.6550814359746081
# Epoch 1 - Training loss: 0.6096912217096612 | validation loss: 0.6891860201003703
# Epoch: 1/24, Train acc: 0.47 | val acc: 0.67
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.6096912217096612 | Minimum validation Loss : 0.6550814359746081
# Epoch 2 - Training loss: 0.678809266639584 | validation loss: 0.665096943175539
# Epoch: 2/24, Train acc: 0.66 | val acc: 0.25
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.5805345721393006 | Minimum validation Loss : 0.5379835698198765
# Epoch 3 - Training loss: 0.5805345721393006 | validation loss: 0.5379835698198765
# Epoch: 3/24, Train acc: 0.62 | val acc: 0.67
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.45054722445211637 | Minimum validation Loss : 0.5379835698198765
# Epoch 4 - Training loss: 0.45054722445211637 | validation loss: 0.5769237804920115
# Epoch: 4/24, Train acc: 0.75 | val acc: 0.83
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.3426367803536342 | Minimum validation Loss : 0.41326929514712474
# Epoch 5 - Training loss: 0.3426367803536342 | validation loss: 0.41326929514712474
# Epoch: 5/24, Train acc: 0.88 | val acc: 0.83
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.25417272444181077 | Minimum validation Loss : 0.3761342023281341
# Epoch 6 - Training loss: 0.25417272444181077 | validation loss: 0.3761342023281341
# Epoch: 6/24, Train acc: 0.94 | val acc: 0.92
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.19622370691959776 | Minimum validation Loss : 0.3761342023281341
# Epoch 7 - Training loss: 0.19622370691959776 | validation loss: 0.4019382920671017
# Epoch: 7/24, Train acc: 0.84 | val acc: 0.92
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.15677797094913679 | Minimum validation Loss : 0.3761342023281341
# Epoch 8 - Training loss: 0.15677797094913679 | validation loss: 0.42862788822422637
# Epoch: 8/24, Train acc: 0.88 | val acc: 1.00
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.1185395427719031 | Minimum validation Loss : 0.3761342023281341
# Epoch 9 - Training loss: 0.1185395427719031 | validation loss: 0.5020543519486772
# Epoch: 9/24, Train acc: 0.97 | val acc: 1.00
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.08683986719646636 | Minimum validation Loss : 0.3761342023281341
# Epoch 10 - Training loss: 0.08683986719646636 | validation loss: 0.5341920404516636
# Epoch: 10/24, Train acc: 1.00 | val acc: 0.92
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.06713064480743199 | Minimum validation Loss : 0.3761342023281341
# Epoch 11 - Training loss: 0.06713064480743199 | validation loss: 0.6182563888265732
# Epoch: 11/24, Train acc: 1.00 | val acc: 0.92
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.05137177115396496 | Minimum validation Loss : 0.3761342023281341
# Epoch 12 - Training loss: 0.05137177115396496 | validation loss: 0.6678523655544887
# Epoch: 12/24, Train acc: 1.00 | val acc: 0.83
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.04188114385311262 | Minimum validation Loss : 0.3761342023281341
# Epoch 13 - Training loss: 0.04188114385311262 | validation loss: 0.7030272903277519
# Epoch: 13/24, Train acc: 1.00 | val acc: 0.92
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.030661265742799038 | Minimum validation Loss : 0.3761342023281341
# Epoch 14 - Training loss: 0.030661265742799038 | validation loss: 0.7390630618570015
# Epoch: 14/24, Train acc: 0.97 | val acc: 0.83
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.029535134219614723 | Minimum validation Loss : 0.3761342023281341
# Epoch 15 - Training loss: 0.029535134219614723 | validation loss: 0.7359856349039585
# Epoch: 15/24, Train acc: 1.00 | val acc: 0.92
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.02297607451849498 | Minimum validation Loss : 0.3761342023281341
# Epoch 16 - Training loss: 0.02297607451849498 | validation loss: 0.736367859136551
# Epoch: 16/24, Train acc: 1.00 | val acc: 0.92
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.022561733817075758 | Minimum validation Loss : 0.3761342023281341
# Epoch 17 - Training loss: 0.022561733817075758 | validation loss: 0.8645981828979356
# Epoch: 17/24, Train acc: 1.00 | val acc: 0.92
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.017010249955113764 | Minimum validation Loss : 0.3761342023281341
# Epoch 18 - Training loss: 0.017010249955113764 | validation loss: 0.9737769433792601
# Epoch: 18/24, Train acc: 1.00 | val acc: 0.75
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.01486077646296995 | Minimum validation Loss : 0.3761342023281341
# Epoch 19 - Training loss: 0.01486077646296995 | validation loss: 1.0032142652951657
# Epoch: 19/24, Train acc: 1.00 | val acc: 0.92
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.01486077646296995 | Minimum validation Loss : 0.3761342023281341
# Epoch 20 - Training loss: 0.015313197387995537 | validation loss: 1.0417869615319006
# Epoch: 20/24, Train acc: 1.00 | val acc: 0.92
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.014197401507815385 | Minimum validation Loss : 0.3761342023281341
# Epoch 21 - Training loss: 0.014197401507815385 | validation loss: 0.888286967999599
# Epoch: 21/24, Train acc: 1.00 | val acc: 0.83
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.005896792327628685 | Minimum validation Loss : 0.3761342023281341
# Epoch 22 - Training loss: 0.005896792327628685 | validation loss: 1.0562652330924855
# Epoch: 22/24, Train acc: 1.00 | val acc: 0.92
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.004570525997316851 | Minimum validation Loss : 0.3761342023281341
# Epoch 23 - Training loss: 0.004570525997316851 | validation loss: 1.1570050987494278
# Epoch: 23/24, Train acc: 1.00 | val acc: 0.83
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.004570525997316851 | Minimum validation Loss : 0.3761342023281341
# Epoch 24 - Training loss: 0.015401575953432127 | validation loss: 1.0069235520972375
# Epoch: 24/24, Train acc: 1.00 | val acc: 0.92
# ------------------------------------------------------------------------------------------
# Training Time(in minutes) = 34.63765473365784

# %%
def evaluate(model, iterator, criterion):
    
    epoch_loss = 0
    epoch_acc = 0
    
    model.eval()
    
    with torch.no_grad():
    
        for batch in iterator:
            
            predictions = model(batch.text).squeeze(1)
            
            loss = criterion(predictions, batch.label)
            
            acc = evaluation_gpu(predictions, batch.label)

            epoch_loss += loss.item()
            epoch_acc += acc.item()
        
    return epoch_loss / len(iterator), epoch_acc / len(iterator)

# %%
model.load_state_dict(valaccmodel)
test_loss, test_acc = evaluate(model, testloader, loss_fn)

print(f'Test Loss: {test_loss:.3f} | Test Acc: {test_acc*100:.2f}%')
# Out:
# Test Loss: 1.076 | Test Acc: 83.88%

# %%
import matplotlib.pyplot as plt

epochs=len(trainloss)
plt.plot([i for i in range(1,epochs+1)],trainloss,label="Train_loss")
plt.plot([i for i in range(1,epochs+1)],valloss,label="Validation_loss")
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
plt.plot([i for i in range(1,epochs+1)],trainacclist,label="Train_Accuracy")
plt.plot([i for i in range(1,epochs+1)],valacclist,label="Validation_Accuracy")
plt.xlabel('epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
