# %%
import torch
from torchtext import data,datasets
import random
import torch.nn as nn
from torch import optim
import numpy as np
import time
import copy

# %% [markdown]
# **Step 1 : Instantiate Text and Label field**

# %%
SEED = 4

torch.manual_seed(SEED)
torch.backends.cudnn.deterministic = True
#create text field to store textdata
#tokenize text data with "spacy" tokenizer
TEXT = data.Field(tokenize = 'spacy')
#create label field to store labels in float
LABEL = data.LabelField(dtype = torch.float)

# %% [markdown]
# **Step 2 : Create data split**

# %%
train_data, test_data = datasets.IMDB.splits(TEXT, LABEL)
print(type(train_data))
print(len(train_data))
print(len(test_data))
# Out:
# downloading aclImdb_v1.tar.gz
# aclImdb_v1.tar.gz: 100%|██████████| 84.1M/84.1M [00:07<00:00, 11.4MB/s]
# <class 'torchtext.datasets.imdb.IMDB'>
# 25000
# 25000

# %%
#create train and validation split from train data
train_data, valid_data = train_data.split(random_state = random.seed(SEED))
#check size of splits
print(len(train_data))
print(len(valid_data))
print(len(test_data))
# Out:
# 17500
# 7500
# 25000

# %% [markdown]
# **Step 3 : Build vocabulary from training data**

# %%
MAX_VOCAB_SIZE = 10000

TEXT.build_vocab(train_data, max_size = MAX_VOCAB_SIZE)
LABEL.build_vocab(train_data)

print("Vocabulary size : ",len(TEXT.vocab))
print("No of different labels : ",len(LABEL.vocab))
# Out:
# Vocabulary size :  10002
# No of different labels :  2

# %%
#print most 20 frequently occured tokens in the corpus
print(TEXT.vocab.freqs.most_common(20))
# Out:
# [('the', 202984), (',', 192815), ('.', 166441), ('a', 109530), ('and', 109365), ('of', 100797), ('to', 93333), ('is', 76572), ('in', 61364), ('I', 54228), ('it', 53270), ('that', 49046), ('"', 44544), ("'s", 43284), ('this', 42307), ('-', 36921), ('/><br', 35672), ('was', 35011), ('as', 30544), ('with', 29785)]

# %%
print(TEXT.vocab.itos[:10])
print(LABEL.vocab.stoi)
# Out:
# ['<unk>', '<pad>', 'the', ',', '.', 'a', 'and', 'of', 'to', 'is']
# defaultdict(<function _default_unk_index at 0x7fe9a5e14e18>, {'neg': 0, 'pos': 1})

# %% [markdown]
# **Step 4 : Create dataloader**

# %%
BATCH_SIZE = 32

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

trainloader, valloader, testloader = data.BucketIterator.splits(
    (train_data, valid_data, test_data), 
    batch_size = BATCH_SIZE,
    device = device)

# %% [markdown]
# **Step 5 : Build model**

# %%
class RNN(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, output_dim):
        
        super().__init__()
        
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        
        self.lstm=nn.RNN(embedding_dim, 
                           hidden_dim, 
                           num_layers=2, 
                           bidirectional=True, 
                           )
        
        self.fc = nn.Linear(hidden_dim*2, 16)
        self.fc2=nn.Linear(16,output_dim)
        self.soft=nn.Softmax(2)
    def forward(self, text):

        #text = [sent len, batch size]
        
        embedded = self.embedding(text)
        
        #embedded = [sent len, batch size, emb dim]
        
        output, hidden = self.lstm(embedded)
        #print(output.shape,hidden.shape,cell.shape)
        #here the return fc have output dim=(batch_size,1)
        hidden=torch.cat((hidden[-2,:,:], hidden[-1,:,:]), dim = 1)
        #assert torch.equal(output[-1,:,:], hidden.squeeze(0))
        ans=self.fc(hidden)
        ans=self.fc2(ans)
        return ans

# %% [markdown]
# **Step 5 : Instanstiate Loss function, Optimizer, Model**

# %%
VOCAB_SIZE = len(TEXT.vocab)
EMBEDDING_DIM = 64
HIDDEN_DIM = 32
OUTPUT_DIM = 1

# %%
def evaluation_gpu(preds, y):
    #round predictions to the closest integer
    rounded_preds = torch.round(torch.sigmoid(preds))
    correct = (rounded_preds == y).float() #convert into float for division 
    acc = correct.sum() / len(correct)
    return acc

# %%
def fit_gpu(trainloader,valloader,model,opt,loss_fn,epochs=25):
        #callback=StopatLossValue()
        time0=time.time()
        trainloss=[]
        valloss=[]
        trainacclist=[]
        valacclist=[]
        min_valloss=10000000.0000000
        min_trainloss=10000000.0000000
        max_valacc=0.0
        max_trainacc=0.0
        
        for epoch in range(epochs):
            runningtrain_loss=0
            runningval_loss=0
            #init_fn()
            for i, data in enumerate(trainloader, 0):

                #inputs, labels = data
                #inputs=inputs.to(device)
                #labels=labels.to(device)

                #forward pass
                predtrain=model(data.text).squeeze(1)
                loss = loss_fn(predtrain, data.label)
                trainacc=evaluation_gpu(predtrain,data.label)
                #backward and optimize
                opt.zero_grad()
                loss.backward()
                opt.step()
                
                
                runningtrain_loss += loss.item()
            #init_fn()
            for i, data in enumerate(valloader,0):
                #inputs, labels = data
                #inputs=inputs.to(device)
                #labels=labels.to(device)

                #forward pass
                predval=model(data.text).squeeze(1)
                loss = loss_fn(predval, data.label)
                valacc=evaluation_gpu(predval,data.label)

                runningval_loss += loss.item()
            avgval_loss=runningval_loss/len(valloader)
            avgtrain_loss=runningtrain_loss/len(trainloader)
            if (avgval_loss<min_valloss):
                min_valloss=avgval_loss    
                vallossmodel=copy.deepcopy(model.state_dict())
            if (avgtrain_loss<min_trainloss):
                min_trainloss=avgtrain_loss
                trainlossmodel=copy.deepcopy(model.state_dict())
            trainacclist.append(trainacc)
            valacclist.append(valacc)
            if (trainacc>max_trainacc):
                max_trainacc=trainacc
                trainaccmodel=copy.deepcopy(model.state_dict())
            if (valacc>max_valacc):
                max_trainacc=valacc
                valaccmodel=copy.deepcopy(model.state_dict())      
            print("Minimum training Loss :",min_trainloss,"| Minimum validation Loss :",min_valloss) 
            print("Epoch {} - Training loss: {}".format(epoch,avgtrain_loss ),"| validation loss: {}".format(avgval_loss))    
            print('Epoch: %d/%d, Train acc: %0.2f' % (epoch, epochs-1,trainacc ),'| val acc: %0.2f' % (valacc))
            print('------------------------------------------------------------------------------------------')
            trainloss.append(avgtrain_loss)       
            valloss.append(avgval_loss)
            #vis.line(Y=avgtrain_loss, opts=dict(showlegend=True))
        print("Training Time(in minutes) =",(time.time()-time0)/60)    
        return vallossmodel,trainlossmodel,valaccmodel,trainaccmodel,trainloss,valloss,trainacclist,valacclist

# %%
model = RNN(VOCAB_SIZE, EMBEDDING_DIM, HIDDEN_DIM, OUTPUT_DIM)
model = model.to(device)
opt = optim.Adam(model.parameters())
loss_fn = nn.BCEWithLogitsLoss()
vallossmodel,trainlossmodel,valaccmodel,trainaccmodel,trainloss,valloss,trainacclist,valacclist=fit_gpu(trainloader,valloader,model,opt,loss_fn)
# Out:
# Minimum training Loss : 0.6857226700189999 | Minimum validation Loss : 0.6867229910607033
# Epoch 0 - Training loss: 0.6857226700189999 | validation loss: 0.6867229910607033
# Epoch: 0/24, Train acc: 0.53 | val acc: 0.58
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.6495785070293782 | Minimum validation Loss : 0.6576859514764015
# Epoch 1 - Training loss: 0.6495785070293782 | validation loss: 0.6576859514764015
# Epoch: 1/24, Train acc: 0.72 | val acc: 0.58
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.5974950321304733 | Minimum validation Loss : 0.641512830713962
# Epoch 2 - Training loss: 0.5974950321304733 | validation loss: 0.641512830713962
# Epoch: 2/24, Train acc: 0.62 | val acc: 0.50
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.5658616585422042 | Minimum validation Loss : 0.6408701989244907
# Epoch 3 - Training loss: 0.5658616585422042 | validation loss: 0.6408701989244907
# Epoch: 3/24, Train acc: 0.62 | val acc: 0.58
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.5358253182942079 | Minimum validation Loss : 0.6361919475362656
# Epoch 4 - Training loss: 0.5358253182942079 | validation loss: 0.6361919475362656
# Epoch: 4/24, Train acc: 0.78 | val acc: 0.58
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.5011550639458069 | Minimum validation Loss : 0.6361919475362656
# Epoch 5 - Training loss: 0.5011550639458069 | validation loss: 0.6533251296966633
# Epoch: 5/24, Train acc: 0.59 | val acc: 0.50
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.47854761964551273 | Minimum validation Loss : 0.6268036764986972
# Epoch 6 - Training loss: 0.47854761964551273 | validation loss: 0.6268036764986972
# Epoch: 6/24, Train acc: 0.75 | val acc: 0.58
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.43819845319339085 | Minimum validation Loss : 0.6268036764986972
# Epoch 7 - Training loss: 0.43819845319339085 | validation loss: 0.6498341007435575
# Epoch: 7/24, Train acc: 0.78 | val acc: 0.50
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.4042039323169091 | Minimum validation Loss : 0.6085115789098943
# Epoch 8 - Training loss: 0.4042039323169091 | validation loss: 0.6085115789098943
# Epoch: 8/24, Train acc: 0.78 | val acc: 0.50
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.4042039323169091 | Minimum validation Loss : 0.6085115789098943
# Epoch 9 - Training loss: 0.4551227326475942 | validation loss: 0.6794193578527329
# Epoch: 9/24, Train acc: 0.53 | val acc: 0.58
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.4042039323169091 | Minimum validation Loss : 0.6085115789098943
# Epoch 10 - Training loss: 0.4268387933099945 | validation loss: 0.6355159893948981
# Epoch: 10/24, Train acc: 0.84 | val acc: 0.58
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.356440360737893 | Minimum validation Loss : 0.6085115789098943
# Epoch 11 - Training loss: 0.356440360737893 | validation loss: 0.6827071603308332
# Epoch: 11/24, Train acc: 0.82 | val acc: 0.50
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.32749033527247867 | Minimum validation Loss : 0.6085115789098943
# Epoch 12 - Training loss: 0.32749033527247867 | validation loss: 0.6865529317805108
# Epoch: 12/24, Train acc: 0.81 | val acc: 0.67
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.2975412870074539 | Minimum validation Loss : 0.6085115789098943
# Epoch 13 - Training loss: 0.2975412870074539 | validation loss: 0.7198785244784457
# Epoch: 13/24, Train acc: 0.88 | val acc: 0.58
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.2630478481215576 | Minimum validation Loss : 0.6085115789098943
# Epoch 14 - Training loss: 0.2630478481215576 | validation loss: 0.7331702555747742
# Epoch: 14/24, Train acc: 0.94 | val acc: 0.67
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.2630478481215576 | Minimum validation Loss : 0.6085115789098943
# Epoch 15 - Training loss: 0.42092734251096436 | validation loss: 0.6662875105725958
# Epoch: 15/24, Train acc: 0.81 | val acc: 0.58
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.2630478481215576 | Minimum validation Loss : 0.6085115789098943
# Epoch 16 - Training loss: 0.3469878480083546 | validation loss: 0.7233358381276435
# Epoch: 16/24, Train acc: 0.91 | val acc: 0.67
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.2630478481215576 | Minimum validation Loss : 0.6085115789098943
# Epoch 17 - Training loss: 0.27948228814647663 | validation loss: 0.8057341741754653
# Epoch: 17/24, Train acc: 0.94 | val acc: 0.58
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.25437454937172327 | Minimum validation Loss : 0.6085115789098943
# Epoch 18 - Training loss: 0.25437454937172327 | validation loss: 0.7680739322241317
# Epoch: 18/24, Train acc: 0.91 | val acc: 0.75
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.21740263297309387 | Minimum validation Loss : 0.6085115789098943
# Epoch 19 - Training loss: 0.21740263297309387 | validation loss: 0.7934887093432406
# Epoch: 19/24, Train acc: 0.81 | val acc: 0.67
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.1820100039597839 | Minimum validation Loss : 0.6085115789098943
# Epoch 20 - Training loss: 0.1820100039597839 | validation loss: 0.9361330100196473
# Epoch: 20/24, Train acc: 1.00 | val acc: 0.67
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.1598412584618987 | Minimum validation Loss : 0.6085115789098943
# Epoch 21 - Training loss: 0.1598412584618987 | validation loss: 0.9741111960182799
# Epoch: 21/24, Train acc: 0.94 | val acc: 0.83
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.1598412584618987 | Minimum validation Loss : 0.6085115789098943
# Epoch 22 - Training loss: 0.19022786547812945 | validation loss: 0.8934959613262339
# Epoch: 22/24, Train acc: 0.88 | val acc: 0.67
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.1381865931977901 | Minimum validation Loss : 0.6085115789098943
# Epoch 23 - Training loss: 0.1381865931977901 | validation loss: 1.0459245600598923
# Epoch: 23/24, Train acc: 0.97 | val acc: 0.67
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 0.1381865931977901 | Minimum validation Loss : 0.6085115789098943
# Epoch 24 - Training loss: 0.14535387649185533 | validation loss: 0.9697163797439413
# Epoch: 24/24, Train acc: 0.94 | val acc: 0.75
# ------------------------------------------------------------------------------------------
# Training Time(in minutes) = 30.78894305229187

# %%
def evaluate(model, iterator, criterion):
    
    epoch_loss = 0
    epoch_acc = 0
    
    model.eval()
    
    with torch.no_grad():
    
        for batch in iterator:
            
            predictions = model(batch.text).squeeze(1)
            
            loss = criterion(predictions, batch.label)
            
            acc = evaluation_gpu(predictions, batch.label)

            epoch_loss += loss.item()
            epoch_acc += acc.item()
        
    return epoch_loss / len(iterator), epoch_acc / len(iterator)

# %%
model.load_state_dict(valaccmodel)
test_loss, test_acc = evaluate(model, testloader, loss_fn)

print(f'Test Loss: {test_loss:.3f} | Test Acc: {test_acc*100:.2f}%')
# Out:
# Test Loss: 0.995 | Test Acc: 69.20%

# %%
import matplotlib.pyplot as plt

epochs=len(trainloss)
plt.plot([i for i in range(1,epochs+1)],trainloss,label="Train_loss")
plt.plot([i for i in range(1,epochs+1)],valloss,label="Validation_loss")
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
plt.plot([i for i in range(1,epochs+1)],trainacclist,label="Train_Accuracy")
plt.plot([i for i in range(1,epochs+1)],valacclist,label="Validation_Accuracy")
plt.xlabel('epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
